# %%
import os
os.getcwd()
# Out:
# '/Users/alanchu/Desktop/uvm-salary-datascience'

# %%
# Import imports for this file to work
import pprint
import numpy as np
import pandas as pd

# %% [markdown]
# ********** Notebook Outline: **********
# **
#
# PART 1: open file that has all data that has all the data & make a pandas dataframe of that data
#
# PART 2: open

# %%
############## PART I #################
# Open file containing all info on people
# filename: "data/allData.txt"

filename = "data/allData.txt"
with open(filename, 'r') as f:
    first_line = f.readline()
    print first_line
f.close()
# Out:
# Commercio,Michele E. ||mcommerc||Michele E Commercio||Political Science||Associate Professor||9 Month Faculty

# %%
############## PART I #################
# Open file containing all info on people
# split all the elements into respective data

filename = "data/allData.txt"
with open(filename, 'r') as f:
    first_line = f.readline().rstrip('\n')
#     print first_line.rstrip('\n')
    # split first_line by '||'
    row_list = first_line.split("||")
    pprint.pprint(row_list)
f.close()
# Out:
# ['Commercio,Michele E. ',
#  'mcommerc',
#  'Michele E Commercio',
#  'Political Science',
#  'Associate Professor',
#  '9 Month Faculty']

# %%
############## PART I #################
# Open file containing all info on people
# order that I saved everything
# original_name, netId, proper_name,
# department, Title, Primary Affiliation

filename = "data/allData.txt"
with open(filename, 'r') as f:
    first_line = f.readline().rstrip('\n')
    # split first_line by '||'
    row_list = first_line.split("||")
    #get rid of the white space on original_name
    row_list[0] = row_list[0].rstrip()
    pprint.pprint(row_list)
f.close()
# Out:
# ['Commercio,Michele E.',
#  'mcommerc',
#  'Michele E Commercio',
#  'Political Science',
#  'Associate Professor',
#  '9 Month Faculty']

# %%
x = np.array([[10, 2], [1,3], [2,4]])
pd.DataFrame(x, columns=["one", "two"])
# Out:
#    one  two
# 0   10    2
# 1    1    3
# 2    2    4

# %%
############## PART I #################
##### Create 5 different lists and add them into a numpy array!
# global variables
allData = []

with open(filename, 'r') as f:
    for line in f:
        row = line.rstrip("\n").split("||")
#         row[0] = row_list[0].rstrip()
        allData.append(row)
        allData[-1][0] = allData[-1][0].rstrip()
f.close()


###################
data = np.array(allData)
df_more_info = pd.DataFrame(data, columns=['original_name', 'netId', "proper_name", "department", "title", "primary_affiliation"])
# df_more_info.shape
df_more_info.tail()
# Out:
#                original_name     netId             proper_name  \
# 1998     Carney,Nancy Ordway   ncarney     Nancy Ordway Carney
# 1999        Morin,Michele H.   mhmorin        Michele H. Morin
# 2000  Gustafson,Thomas James  tjgustaf  Thomas James Gustafson
# 2001       Swartwout,Katryna  kswartwo          Katryna A Snow
# 2002             Zolj,Ferida     fzolj             Ferida Zolj
#
#                        department                          title  \
# 1998  Ctr for Health & Well Being              Health Care Nurse
# 1999     Continuing Med Education           Conference Assistant
# 2000       VP Univ Reltns & Admin  VP Univ Relations &amp; Admin
# 2001                   Admissions  Enrollment Mgmnt Professnl Sr
# 2002           Custodial Services   Custodial Maintenance Worker
#
#      primary_affiliation
# 1998      12 Month Staff
# 1999      12 Month Staff
# 2000      12 Month Staff
# 2001      12 Month Staff
# 2002      12 Month Staff

# %%
#### get the unique
############## PART I #################
##### Create 5 different lists and add them into a numpy array!
# global variables
allData = []

with open(filename, 'r') as f:
    for line in f:
        row = line.rstrip("\n").split("||")
#         row[0] = row_list[0].rstrip()
        allData.append(row)
        allData[-1][0] = allData[-1][0].rstrip()
f.close()


###################
data = np.array(allData)
df_more_info = pd.DataFrame(data, columns=['original_name', 'netId', "proper_name", "department", "title", "primary_affiliation"])
# get unique entries
df_more_info.drop_duplicates(subset="netId", inplace = True)
# print df_more_info

# df_more_info.shape
df_more_info.tail()
# Out:
#                original_name     netId             proper_name  \
# 1998     Carney,Nancy Ordway   ncarney     Nancy Ordway Carney
# 1999        Morin,Michele H.   mhmorin        Michele H. Morin
# 2000  Gustafson,Thomas James  tjgustaf  Thomas James Gustafson
# 2001       Swartwout,Katryna  kswartwo          Katryna A Snow
# 2002             Zolj,Ferida     fzolj             Ferida Zolj
#
#                        department                          title  \
# 1998  Ctr for Health & Well Being              Health Care Nurse
# 1999     Continuing Med Education           Conference Assistant
# 2000       VP Univ Reltns & Admin  VP Univ Relations &amp; Admin
# 2001                   Admissions  Enrollment Mgmnt Professnl Sr
# 2002           Custodial Services   Custodial Maintenance Worker
#
#      primary_affiliation
# 1998      12 Month Staff
# 1999      12 Month Staff
# 2000      12 Month Staff
# 2001      12 Month Staff
# 2002      12 Month Staff

# %%
df_allData = pd.read_csv(filepath_or_buffer="data/uvm_employee_salary_data_1994-2014.csv")

# CODE BELOW works, drops duplicates
# df_allData.drop_duplicates(subset="Name", inplace = True)

# Get only for 2014
# df_allData_2014[df_allData_2014.Year == 2014]
df_allData_2014 = pd.DataFrame(df_allData.loc[df_allData_2014.Year == 2014])

df_allData_2014.head()
# df_allData_2014.size
# Out:
#     Year                    Name                  Position  Salary
# 0   2014  Morin III,Frederick C.                      Dean  544666
# 6   2014      Sullivan,E. Thomas                 President  429093
# 8   2014       Rosowsky,David V.  Senior Vice Pres/Provost  383438
# 10  2014      Stein,Gary Stephen                 Professor  372908
# 13  2014           Sharma,Sanjay                      Dean  343423

# %%
## merge the two dataframes

# df_complete = pd.concat([df_more_info, df_allData], axis=1)
df_complete_2014 = pd.merge(df_more_info, df_allData_2014, left_on="original_name", right_on="Name", how="outer")
# df_complete.tail()
# df_test.head()
# df_complete.shape
df_complete_2014[:7]
# Out:
#           original_name     netId          proper_name  \
# 0  Commercio,Michele E.  mcommerc  Michele E Commercio
# 1   Desjardins,Isabelle  idesjard  Isabelle Desjardins
# 2   Boland Chira,Sheila  sbolandc  Sheila Boland Chira
# 3        AbuJaish,Wasef  wabujais       Wasef AbuJaish
# 4        Boal,Robert J.     rboal        Robert J Boal
# 5     Herrick,Cheryl L.  clherric     Cheryl L Herrick
# 6      Hall,Margaret A.    mahall      Margaret A Hall
#
#                        department                       title  \
# 0               Political Science         Associate Professor
# 1                      Psychiatry         Associate Professor
# 2                         English             Senior Lecturer
# 3                    Surg-General         Associate Professor
# 4             Physical Plant Dept  Building Controls Engineer
# 5  Ext - Sustainable Agricltr Ctr    Outreach Program Support
# 6         Sponsored Project Admin   Business/Acctng Specialst
#
#   primary_affiliation  Year                  Name  \
# 0     9 Month Faculty  2014  Commercio,Michele E.
# 1    12 Month Faculty  2014   Desjardins,Isabelle
# 2     9 Month Faculty  2014   Boland Chira,Sheila
# 3    12 Month Faculty  2014        AbuJaish,Wasef
# 4      12 Month Staff  2014        Boal,Robert J.
# 5      12 Month Staff  2014     Herrick,Cheryl L.
# 6      12 Month Staff  2014      Hall,Margaret A.
#
#                          Position  Salary
# 0             Associate Professor   76824
# 1             Associate Professor   30600
# 2                 Senior Lecturer   55784
# 3             Assistant Professor   35000
# 4      Facilities Trades Engineer   62046
# 5  Office/Prgm Support Generalist   38855
# 6      Business/Acctng Specialist   44662

# %%
df_complete_2014 = pd.merge(df_more_info, df_allData_2014, left_on="original_name", right_on="Name", how="outer")

df_complete_2014.tail()
# Out:
#      original_name netId proper_name department title primary_affiliation  \
# 3903           NaN   NaN         NaN        NaN   NaN                 NaN
# 3904           NaN   NaN         NaN        NaN   NaN                 NaN
# 3905           NaN   NaN         NaN        NaN   NaN                 NaN
# 3906           NaN   NaN         NaN        NaN   NaN                 NaN
# 3907           NaN   NaN         NaN        NaN   NaN                 NaN
#
#       Year                 Name                        Position  Salary
# 3903  2014        Burt,Keith B.             Associate Professor       0
# 3904  2014  Gross,Kenneth Irwin                       Professor       0
# 3905  2014          Cox,Lee Ann  Communications Professional Sr       0
# 3906  2014  Allen,James Patrick          Library Support Senior       0
# 3907  2014      Walrath,Dana E.         Research Assistant Prof       0

# %% [markdown]
# Sweet! This looks like it works!

# %% [markdown]
# PART 2: try to get all the unique departments
#
# # 1.) Get a series of unique department names

# %%
# 1.) Get a series of the unique departments

df_unique_departments_2014 = pd.DataFrame(df_complete_2014)
unique_departments_2014 = pd.Series(df_unique_departments_2014.department)
unique_departments_2014.tail()
# Out:
# 3903    NaN
# 3904    NaN
# 3905    NaN
# 3906    NaN
# 3907    NaN
# Name: department, dtype: object

# %%
# 1.) Get a series of the unique departments

df_unique_departments_2014 = pd.DataFrame(df_complete_2014)
unique_departments_2014 = pd.Series(df_unique_departments_2014.department)
unique_departments_2014.tail()
